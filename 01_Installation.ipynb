# %% [markdown]
# ## **Install pyrorch in windows:**
#
# - go to official website: pytorch.org
#
# - start locally:
#
# > pytorch build: stable(1.12.1)
#
# > your os: windows
#
# > Package: Conda
#
# > Language: Python
#
# > Compute platform: CPU
#
# *if you have Nvidia, you must be install it first. then select CUDA
#
# - Copy the command that generate
#
# - make an environment for pytorch
#
# - install pytorch with command in pytorch environment

# %% [markdown]
# # **Install pytorch in Google Colab:**
#
# - Recently Google Colab comes preinstalled with pytorch, which removes the need to install it manualy, unless a specific version is required.

# %% [markdown]
# check CUDA version in Colab

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %% [markdown]
# check Python version in Colab

# %%
# !python --version
# Out:
# Python 3.7.13

# %% [markdown]
# check Pytorch version in Colab

# %%
import torch

torch.__version__
# Out:
# '1.12.1+cu113'

# %% [markdown]
# To confirm GPU is set up, you can run the following line after importing PyTorch and change runtime type to GPU:

# %%
import torch
torch.cuda.get_device_name(0)
# Out:
# 'Tesla T4'

# %% [markdown]
# Tesla T4 specifications are as follows:

# %% [markdown]
# ![Tesla_T4.png](data:image/png;base64,...)
